# %%
import pandas as pd

# %%
email = open("../datasets/trec07p/full/index").readlines()

# %%
email
# Out:
# ['spam ../data/inmail.1\n',
#  'ham ../data/inmail.2\n',
#  'spam ../data/inmail.3\n',
#  'spam ../data/inmail.4\n',
#  'spam ../data/inmail.5\n',
#  'spam ../data/inmail.6\n',
#  'spam ../data/inmail.7\n',
#  'spam ../data/inmail.8\n',
#  'spam ../data/inmail.9\n',
#  'ham ../data/inmail.10\n',
#  'spam ../data/inmail.11\n',
#  'spam ../data/inmail.12\n',
#  'spam ../data/inmail.13\n',
#  'spam ../data/inmail.14\n',
#  'spam ../data/inmail.15\n',
#  'spam ../data/inmail.16\n',
#  'spam ../data/inmail.17\n',
#  'spam ../data/inmail.18\n',
#  'spam ../data/inmail.19\n',
#  'ham ../data/inmail.20\n',
#  'ham ../data/inmail.21\n',
#  'spam ../data/inmail.22\n',
#  'spam ../data/inmail.23\n',
#  'spam ../data/inmail.24\n',
#  'spam ../data/inmail.25\n',
#  'spam ../data/inmail.26\n',
#  'spam ../data/inmail.27\n',
#  'spam ../data/inmail.28\n',
#  'ham ../data/inmail.29\n',
#  'spam ../data/inmail.30\n',
#  'ham ../data/inmail.31\n',
#  'spam ../data/inmail.32\n',
# ...

# %%
email_mod = [palabra.replace("../","").replace("\n","").split(" ") for palabra in email]

# %%
email_mod
# Out:
# [['spam', 'data/inmail.1'],
#  ['ham', 'data/inmail.2'],
#  ['spam', 'data/inmail.3'],
#  ['spam', 'data/inmail.4'],
#  ['spam', 'data/inmail.5'],
#  ['spam', 'data/inmail.6'],
#  ['spam', 'data/inmail.7'],
#  ['spam', 'data/inmail.8'],
#  ['spam', 'data/inmail.9'],
#  ['ham', 'data/inmail.10'],
#  ['spam', 'data/inmail.11'],
#  ['spam', 'data/inmail.12'],
#  ['spam', 'data/inmail.13'],
#  ['spam', 'data/inmail.14'],
#  ['spam', 'data/inmail.15'],
#  ['spam', 'data/inmail.16'],
#  ['spam', 'data/inmail.17'],
#  ['spam', 'data/inmail.18'],
#  ['spam', 'data/inmail.19'],
#  ['ham', 'data/inmail.20'],
#  ['ham', 'data/inmail.21'],
#  ['spam', 'data/inmail.22'],
#  ['spam', 'data/inmail.23'],
#  ['spam', 'data/inmail.24'],
#  ['spam', 'data/inmail.25'],
#  ['spam', 'data/inmail.26'],
#  ['spam', 'data/inmail.27'],
#  ['spam', 'data/inmail.28'],
#  ['ham', 'data/inmail.29'],
#  ['spam', 'data/inmail.30'],
#  ['ham', 'data/inmail.31'],
#  ['spam', 'data/inmail.32'],
# ...

# %%
df = pd.DataFrame(email_mod,columns=["Label","Feature"])

# %%
df
# Out:
#       Label            Feature
# 0      spam      data/inmail.1
# 1       ham      data/inmail.2
# 2      spam      data/inmail.3
# 3      spam      data/inmail.4
# 4      spam      data/inmail.5
# ...     ...                ...
# 75414  spam  data/inmail.75415
# 75415  spam  data/inmail.75416
# 75416   ham  data/inmail.75417
# 75417   ham  data/inmail.75418
# 75418  spam  data/inmail.75419
#
# [75419 rows x 2 columns]
